# %%
import matplotlib.pyplot as plt
# matplotlib is used for low level ploting  in this function we are making a high function small small function

# %%
# line plot data 
X=[1,2,3.4,4]
y=[5,6,7,9.9]
plt.plot(X,y)
plt.show()

# %%
import matplotlib.pyplot as plt

# Oscar Winner Movies
oscar_movies = [
    "The Dark Knight",
    "The Hurt Locker",
    "The King's Speech",
    "The Artist",
    "Argo"
]

# Years properly assign kara
years = [2008, 2009, 2010, 2011, 2012]

# Revenue (in $M)
oscar_revenue = [1005, 170, 427, 133, 232]

# Plot
plt.plot(years, oscar_revenue, marker='s')
# ya mde march function aahe ki tya point la line creat hote tya point la yek sym dene marker='x'   # cross
# marker='s'   # square
# marker='^'   # triangle

plt.title("Oscar Movies Revenue in each Year")
plt.xlabel("Years")
plt.ylabel("Revenue (in $M)")

plt.show()

# %%
import matplotlib.pyplot as plt

years = [2008, 2009, 2010, 2011, 2012]

oscar_revenue = [1005, 170, 427, 133, 232]
non_oscar_revenue = [123, 422, 3445, 3234, 4555]

# Plot Oscar movies
plt.plot(years, oscar_revenue, marker="s", label="Oscar Movies")

# Plot Non-Oscar movies
plt.plot(years, non_oscar_revenue, marker="o", label="Non-Oscar Movies")

plt.title("Oscar Movie Revenue vs Non-Oscar Movie Revenue")
plt.xlabel("Years")
plt.ylabel("Revenue (in $M)")

plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt

# Simple data
x = [1, 2, 3]
y = [2, 4, 3]

# style list (optional print)
print(plt.style.available)

# use style
# plt.style.use('ggplot')

# plot
plt.plot(x, y)

# grid
plt.grid()

# layout
plt.tight_layout()

# save figure
plt.savefig("abc.png")

# show
plt.show()
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
# movies - revenue
movies = [
"The Dark Knight",
"The Hurt Locker",
"The King's Speech",
"The Artist",
"Argo"
]
years = [2008, 2009, 2010, 2011, 2012]
revenue = [1005, 170, 427, 133, 232] # in $M

plt.plot(movies, revenue,marker="s")
plt.style.use("default")
plt.title("movie revenue ")
plt.tight_layout() # make  best structur in label 
plt.savefig("sidharthpic.png") # save the pfg

# %%
import matplotlib.pyplot as plt

years = [2008, 2009, 2010, 2011, 2012]

oscar_revenue = [5005, 170, 427, 133, 232]
non_oscar_revenue = [123, 422, 3445, 3234, 4555]

# Plot Oscar movies
plt.plot(years, oscar_revenue,"o-.g",color="#E6CCFF", marker="s", label="Oscar Movies")

# Plot Non-Oscar movies
plt.plot(years, non_oscar_revenue, marker="o", label="Non-Oscar Movies")

plt.title("Oscar Movie Revenue vs Non-Oscar Movie Revenue")
plt.xlabel("Years")
plt.ylabel("Revenue (in $M)")

plt.legend()

plt.show()
# "0--r"  lines---colour
# Out:
# C:\Users\Siddharth\AppData\Local\Temp\ipykernel_16420\1498906417.py:9: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o-.g" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(years, oscar_revenue,"o-.g",color="#E6CCFF", marker="s", label="Oscar Movies")
# C:\Users\Siddharth\AppData\Local\Temp\ipykernel_16420\1498906417.py:9: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "o-.g" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(years, oscar_revenue,"o-.g",color="#E6CCFF", marker="s", label="Oscar Movies")

# %%
 # Real data

# Oscar Winner Movies
oscar_movies = [
"The Dark Knight",
"The Hurt Locker",
"The King's Speech",
"The Artist",
"Argo"
]
years = [2008, 2009, 2010, 2011, 2012]
oscar_revenue = [1005, 170, 427, 133, 232] # in $M

# Plot
plt.plot(years, oscar_revenue,marker="s")
plt.grid(False)

plt.title("oscar revenue of each  data")
plt.xlabel("years")
plt.ylabel("revenue (in $M )")
# Out:
# Text(0, 0.5, 'revenue (in $M )')

# %%
# bar chat  Bar Charts
# A bar plot (or bar chart) is a graph that displays categorical data using rectangular bars.
# Each bar's height (or length, in horizontal bars) represents a value.
movies = [
"The Dark Knight",
"The Hurt Locker",
"The King's Speech",
"The Artist",
"Argo"
]
years = [2008, 2009, 2010, 2011, 2012]
oscar_revenue = [65, 170, 427, 133, 232] # in $M
plt.bar(years,oscar_revenue,color="GREEN")
plt.title("revenue in each years  in vertically format ")
plt.xlabel("years")
plt.ylabel("oscar_revenue")
# Out:
# Text(0, 0.5, 'oscar_revenue')

# %%
# comparing data with bar charts
oscar_movies = ["The Dark Knight","The Hurt Locker","The King's Speech","The Artist","Argo"]
oscar_revenue = [1005, 170, 427, 133, 232]  # in $M

non_oscar_movies = ["Slumdog Millionaire","Avatar","Inception","Hugo","Lincoln"]
non_oscar_revenue = [378, 2788, 829, 185, 275]  # in $M

years = [2008, 2009, 2010, 2011, 2012]

# Plotting Bar Chart
import numpy as np
x = np.arange(len(years))
width = 0.3

plt.bar(x-width/2, oscar_revenue, width, label="Oscar")
plt.bar(x+width/2, non_oscar_revenue, width, label="Non-Oscar")

plt.xlabel("Years")
plt.ylabel("Revenue (in $M)")
plt.title("Yearly revenue of Oscar vs Non-Oscar movies")
plt.legend()
plt.tight_layout()

plt.xticks(x, years) # to show x-axis labels
# Out:
# ([<matplotlib.axis.XTick at 0x291c254dbd0>,
# ...
#  [Text(0, 0, '2008'),
#   Text(1, 0, '2009'),
#   Text(2, 0, '2010'),
#   Text(3, 0, '2011'),
#   Text(4, 0, '2012')])

# %%
movies = [
"The Dark Knight",
"The Hurt Locker",
"The King's Speech",
"The Artist",
"Argo"
]
years = [2008, 2009, 2010, 2011, 2012]
plt.barh(oscar_movies,oscar_revenue)
plt.title("revenue in bar char in horizontal format ")
plt.xlabel("revenue")
plt.ylabel("movies_name")
# Out:
# Text(0, 0.5, 'movies_name')

# %%
# Scatter Plots
# A scatter plot shows the relationship between two variables by plotting points on a 2D plane.
# to check coreleation ,outliess,cluster 
# Scatter Plots

people = ["Person A", "Person B", "Person C", "Person D", "Person E",
          "Person F", "Person G", "Persn H", "Person I", "Person J"]
age = [22, 25, 30, 35, 40, 45, 50, 55, 60, 65]
bp= [110, 115, 120, 122, 125, 130, 135, 123, 145, 150]
plt.scatter(age,bp)
plt.title("age vs bp")
plt.xlabel("age")
plt.ylabel("blood_pressure")
plt.grid()# making box  on the scatter graph

# %%
# Multiple Plots

cities = ["City A", "City B", "City C", "City D", "City E"]

# Winter: Temperature ("C) vs Humidity (%)
winter_temp = [5, 2, 10, 0, 7]
winter_humidity = [80, 75, 65, 85, 70]

# Sumer: Temperature (C) vs Humidity (%)
summer_temp = [25, 30, 28, 35, 27]
summer_humidity = [60, 50, 55, 45, 65]

plt.scatter(winter_temp,winter_humidity,label="Winter")
plt.scatter(summer_temp,summer_humidity,label="summer")
plt.legend()
plt.title("summervs winter ")
plt.xlabel("tempecture")
plt.ylabel("humidity")A
# Out:
# Text(0, 0.5, 'humidity')

# %%
# Scatter Plots

people = ["Person A", "Person B", "Person C", "Person D", "Person E"
          "Person F", "Person G", "Person H", "Person I", "Person J"]
age = [22, 25, 30, 35, 40, 45, 50, 55, 60, 65]
bp = [110, 115, 120, 122, 125, 130, 135, 123, 145, 150]

colour=["red","yellow","pink"]
plt.scatter(age, bp, color="red")
plt.title("Age vs BP")
plt.xlabel("Age")
plt.ylabel("Blood Pressure")

plt.grid()

# %%
# Pie Charts
# A pie chart is a circular chart divided into slices to show relative proportions of a whole.
# . Each slice = a category
# · Size of slice = value of that category relative to total
 
# Prefer them only for few categories.
# in pie chat maximum category is 5 to 6 only
# Pie Charts
expenses = ["Salaries", "Rent", "Marketing", "R&D", "Miscellaneous"]

colors = ["red", "black", "pink", "blue", "yellow"] # usedf  for customm coreor ani te pie chat made pass karaycha method colours chi 
amounts = [500, 150, 120, 100, 50]
plt.style.use("classic") # using a style methodn on pie chart 

wedgeprops = {
"edgecolor": "black",
"linewidth": 5,
"linestyle": " __ "}
plt.pie(amounts,labels=expenses,autopct="1.1f%%",colors=colors)
# autopct gives a persentag in
