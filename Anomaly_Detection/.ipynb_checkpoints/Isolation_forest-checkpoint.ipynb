# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv("thyroid_dataset.csv")

df.head()

x=df.drop("Outlier_label",axis=1)
y=df["Outlier_label"]

scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)

from sklearn.ensemble import IsolationForest

isolation_forest = IsolationForest(
    n_estimators=200,
    random_state=42
)

labels = isolation_forest.fit_predict(x_scaled)

print(labels)

labels=IsolationForest.fir_predict(x_scaled)
# Out:
# [ 1  1 -1 ...  1  1  1]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 26
#      22 labels = isolation_forest.fit_predict(x_scaled)
#      24 print(labels)
# ---> 26 labels=IsolationForest.fir_predict(x_scaled)
#
# AttributeError: type object 'IsolationForest' has no attribute 'fir_predict'

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=2)
x_pca=pca.fit_transform(x_scaled)

# %%
plt.figure(figsize=(8,6))
