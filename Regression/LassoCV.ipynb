# %%
import numpy as np
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split

# Sample dataset (replace with your actual data)
np.random.seed(42)
X = np.random.rand(100, 5)   # 100 samples, 5 features
y = np.random.rand(100)       # 100 target values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = Lasso(alpha=0.1)
model.fit(X_train, y_train)

print(model.coef_)
# Out:
# [0. 0. 0. 0. 0.]

# %%
from sklearn. linear_model import LassoCV
a = [0.001, 0.1, 1, 2, 5, 10, 20, 30, 40, 50, 100]

lasso_cv_model = LassoCV(
alphas=a,
cv=5,
max_iter=1000,
random_state=42
)
lasso_cv_model.fit(X_train, y_train)

print("best alpha: ", lasso_cv_model.alpha_)
# Out:
# best alpha:  0.001

# %%
#LassoCV is used to improve a regression model and reduce overfitting. 
# It automatically selects the most important features and finds the best alpha value using cross-validation.
